# %%
import pandas as pd
factors = pd.read_parquet('tmp/factors.parquet')

factors.iloc[60:65, :6].round(4)
# Out:
#             daily_return_AAPL  daily_return_MSFT  daily_return_GOOGL  \
# Date
# 2021-03-31             0.0188             0.0169              0.0078
# 2021-04-01             0.0070             0.0279              0.0326
# 2021-04-05             0.0236             0.0277              0.0419
# 2021-04-06             0.0025            -0.0049             -0.0044
# 2021-04-07             0.0134             0.0082              0.0135
#
#             daily_return_JPM  daily_return_XOM  daily_return_SPY
# Date
# 2021-03-31           -0.0146           -0.0152            0.0041
# 2021-04-01            0.0097            0.0279            0.0108
# 2021-04-05            0.0053           -0.0155            0.0144
# 2021-04-06           -0.0070           -0.0028           -0.0006
# 2021-04-07            0.0157            0.0044            0.0012
